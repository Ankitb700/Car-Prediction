# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importing the dataset

# %%
df = pd.read_csv("merged_car_data.csv")

# %%
df.shape
# Out:
# (539126, 8)

# %%
df.head()
# Out:
#    Price  Year  Mileage         City State                Vin   Make  \
# 0  15777  2015    25195  New Orleans    LA  KL4CJASB4FB217542  Buick
# 1  16895  2015    21026    Souderton    PA  KL4CJASB9FB190502  Buick
# 2  15995  2015    20496    McDonough    GA  KL4CJBSB2FB101567  Buick
# 3  17991  2016    14806       Tucson    AZ  KL4CJASB7GB620898  Buick
# 4   3950  2003   176935      Elkhart    IN  3G5DA03E93S607122  Buick
#
#                Model
# 0          EncoreFWD
# 1          EncoreFWD
# 2  EncoreConvenience
# 3          EncoreFWD
# 4      RendezvousCXL

# %% [markdown]
# Feature Engineering for model prediction
# >We are frequency encoding the columns and converting the categorical columns into numerical encoding for model prediction

# %%
cat_cols = ['Mileage', 'City', 'State','Make','Model']

# perform frequency encoding on each column
for col in cat_cols:
    freq_encoding = df[col].value_counts(normalize=True)
    df[f'{col}_freq_encoded'] = df[col].map(freq_encoding)

# %%
df.head()
# Out:
#    Price  Year  Mileage         City State                Vin   Make  \
# 0  15777  2015    25195  New Orleans    LA  KL4CJASB4FB217542  Buick
# 1  16895  2015    21026    Souderton    PA  KL4CJASB9FB190502  Buick
# 2  15995  2015    20496    McDonough    GA  KL4CJBSB2FB101567  Buick
# 3  17991  2016    14806       Tucson    AZ  KL4CJASB7GB620898  Buick
# 4   3950  2003   176935      Elkhart    IN  3G5DA03E93S607122  Buick
#
#                Model  Mileage_freq_encoded  City_freq_encoded  \
# 0          EncoreFWD              0.000017           0.000479
# 1          EncoreFWD              0.000017           0.000252
# 2  EncoreConvenience              0.000020           0.000658
# 3          EncoreFWD              0.000007           0.005112
# 4      RendezvousCXL              0.000004           0.000746
#
#    State_freq_encoded  Make_freq_encoded  Model_freq_encoded
# 0            0.010339           0.014197            0.000692
# 1            0.032072           0.014197            0.000692
# 2            0.044923           0.014197            0.000614
# 3            0.027509           0.014197            0.000692
# 4            0.017738           0.014197            0.000009

# %% [markdown]
# Droping all the columns that are not necessary for the model prediction

# %%
df.drop(columns=['City', 'State','Make','Model','Vin'],inplace=True)

# %% [markdown]
# Creating new features and columns
# >Creating year column : how much is the car driven
# >avg_mileage_per_year : mileage of the car with respect to year

# %%
import datetime

current_year = datetime.datetime.now().year
df['Years_Ago'] = current_year - df['Year']

# %%
df['Avg_Mileage_Per_Year'] = df['Mileage'] / df['Years_Ago']

# %%
df.head()
# Out:
#    Price  Year  Mileage  Mileage_freq_encoded  City_freq_encoded  \
# 0  15777  2015    25195              0.000017           0.000479
# 1  16895  2015    21026              0.000017           0.000252
# 2  15995  2015    20496              0.000020           0.000658
# 3  17991  2016    14806              0.000007           0.005112
# 4   3950  2003   176935              0.000004           0.000746
#
#    State_freq_encoded  Make_freq_encoded  Model_freq_encoded  Years_Ago  \
# 0            0.010339           0.014197            0.000692          8
# 1            0.032072           0.014197            0.000692          8
# 2            0.044923           0.014197            0.000614          8
# 3            0.027509           0.014197            0.000692          7
# 4            0.017738           0.014197            0.000009         20
#
#    Avg_Mileage_Per_Year
# 0           3149.375000
# 1           2628.250000
# 2           2562.000000
# 3           2115.142857
# 4           8846.750000

# %% [markdown]
# Checkinh the correlation matrix of the new features

# %%
df.corr()
# Out:
#                          Price      Year   Mileage  Mileage_freq_encoded  \
# Price                 1.000000  0.415153 -0.435329              0.094281
# Year                  0.415153  1.000000 -0.766522              0.143218
# Mileage              -0.435329 -0.766522  1.000000             -0.174414
# Mileage_freq_encoded  0.094281  0.143218 -0.174414              1.000000
# City_freq_encoded     0.007772  0.010739 -0.005410             -0.000645
# State_freq_encoded    0.038477  0.053831 -0.049662              0.009725
# Make_freq_encoded    -0.075001  0.028228  0.041204             -0.009937
# Model_freq_encoded    0.065202  0.010462  0.019039             -0.008617
# Years_Ago            -0.415153 -1.000000  0.766522             -0.143218
# Avg_Mileage_Per_Year -0.379339 -0.450445  0.879893             -0.179513
#
#                       City_freq_encoded  State_freq_encoded  \
# Price                          0.007772            0.038477
# Year                           0.010739            0.053831
# Mileage                       -0.005410           -0.049662
# Mileage_freq_encoded          -0.000645            0.009725
# City_freq_encoded              1.000000            0.304702
# State_freq_encoded             0.304702            1.000000
# Make_freq_encoded             -0.031554           -0.029272
# Model_freq_encoded            -0.023084           -0.020618
# Years_Ago                     -0.010739           -0.053831
# Avg_Mileage_Per_Year          -0.000779           -0.036278
#
#                       Make_freq_encoded  Model_freq_encoded  Years_Ago  \
# Price                         -0.075001            0.065202  -0.415153
# Year                           0.028228            0.010462  -1.000000
# Mileage                        0.041204            0.019039   0.766522
# Mileage_freq_encoded          -0.009937           -0.008617  -0.143218
# City_freq_encoded             -0.031554           -0.023084  -0.010739
# State_freq_encoded            -0.029272           -0.020618  -0.053831
# Make_freq_encoded              1.000000            0.235334  -0.028228
# Model_freq_encoded             0.235334            1.000000  -0.010462
# Years_Ago                     -0.028228           -0.010462   1.000000
# Avg_Mileage_Per_Year           0.081000            0.036305   0.450445
#
#                       Avg_Mileage_Per_Year
# Price                            -0.379339
# Year                             -0.450445
# Mileage                           0.879893
# Mileage_freq_encoded             -0.179513
# City_freq_encoded                -0.000779
# State_freq_encoded               -0.036278
# Make_freq_encoded                 0.081000
# Model_freq_encoded                0.036305
# Years_Ago                         0.450445
# Avg_Mileage_Per_Year              1.000000

# %% [markdown]
# Spliting the dataset into x_train,x_test in a ratio of 80% - 20%

# %%
from sklearn.model_selection import train_test_split
x = df[['Year','Mileage','Mileage_freq_encoded','City_freq_encoded','State_freq_encoded','Make_freq_encoded','Model_freq_encoded','Years_Ago','Avg_Mileage_Per_Year']]
y = df['Price']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#         Year  Mileage  Mileage_freq_encoded  City_freq_encoded  \
# 534355  2014    16523              0.000011           0.000527
# 245288  2014    21005              0.000026           0.001475
# 30990   2014    19005              0.000017           0.008147
# 72078   2005   125280              0.000009           0.000089
# 465651  2013    31340              0.000028           0.002782
# ...      ...      ...                   ...                ...
# 110268  2012    90104              0.000006           0.000137
# 259178  2017     8432              0.000015           0.000939
# 365838  2014    36603              0.000017           0.000108
# 131932  2015    72141              0.000002           0.003125
# 121958  2014    29126              0.000011           0.000121
#
#         State_freq_encoded  Make_freq_encoded  Model_freq_encoded  Years_Ago  \
# 534355            0.011446           0.027290            0.003658          9
# 245288            0.097747           0.016108            0.003016          9
# 30990             0.017055           0.116168            0.013648          9
# 72078             0.026573           0.041881            0.000386         18
# 465651            0.003981           0.057130            0.012923         10
# ...                    ...                ...                 ...        ...
# 110268            0.019943           0.120764            0.029325         11
# 259178            0.097747           0.031137            0.000288          6
# 365838            0.092157           0.057130            0.002645          9
# 131932            0.027179           0.120764            0.002281          8
# 121958            0.017055           0.120764            0.007852          9
#
#         Avg_Mileage_Per_Year
# 534355           1835.888889
# 245288           2333.888889
# 30990            2111.666667
# 72078            6960.000000
# 465651           3134.000000
# ...                      ...
# 110268           8191.272727
# 259178           1405.333333
# 365838           4067.000000
# 131932           9017.625000
# 121958           3236.222222
#
# [431300 rows x 9 columns]

# %%
y_train
# Out:
# 534355    15991
# 245288    13499
# 30990     32500
# 72078      8995
# 465651    13995
#           ...
# 110268    19944
# 259178    36525
# 365838    15988
# 131932    11980
# 121958    20300
# Name: Price, Length: 431300, dtype: int64

# %% [markdown]
# Using minmaxscaler to convert all the larger values and bringing them into a ascale of 0-1 for model prediction

# %%
from sklearn.preprocessing import MinMaxScaler
# Create an instance of MinMaxScaler
scaler = MinMaxScaler()

# Scale the features using fit_transform() method
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

# %%
X_train_scaled[0]
# Out:
# array([0.80952381, 0.00578323, 0.01096491, 0.03213353, 0.09949033,
#        0.22596996, 0.12467582, 0.19047619, 0.00746799])

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import cross_val_score

# %%
# Create linear regression model
lr_model = LinearRegression()

# Train model on training set
lr_model.fit(X_train_scaled, y_train)

# Make predictions on test set
y_pred = lr_model.predict(X_test_scaled)

# Calculate root mean squared error on test set
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print("R2:",r2)
print("Mae:",mae)
print("Mse:",mse)
print("RMSE:", rmse)
# Out:
# R2: 0.234116704066608
# Mae: 7454.011453638269
# Mse: 144711770.31146476
# RMSE: 12029.620538964009

# %% [markdown]
# Regid Model

# %%
from sklearn.linear_model import Ridge

# Create ridge regression model
ridge_model = Ridge(alpha=1.0)

# Train model on training set
ridge_model.fit(X_train_scaled, y_train)

# Make predictions on test set
y_pred = ridge_model.predict(X_test_scaled)

# Calculate R2 and MSE on test set
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print("R2:", r2)
print("MAE:", mae)
print("MSE:", mse)
# Out:
# R2: 0.23352679302390833
# MAE: 7454.011453638269
# MSE: 144823232.5561287

# %% [markdown]
# Random Forest Regression model With PCA

# %%
from sklearn.decomposition import PCA

# Apply PCA to reduce dimensionality
pca = PCA(n_components=4)
X_pca = pca.fit_transform(X_train_scaled)

# Train random forest model
rf_model = RandomForestRegressor(n_estimators=40, random_state=20)
rf_model.fit(X_train_scaled, y_train)

# Make predictions on test set
y_pred = rf_model.predict(X_test_scaled)

# Evaluate model performance
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
medae = median_absolute_error(y_test, y_pred)

print("R2:", r2)
print("MSE:", mse)
print("MAE:", mae)
print("MedAE:", medae)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\HP\Downloads\car_analysis\modeling.ipynb Cell 30 in 8
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Downloads/car_analysis/modeling.ipynb#X41sZmlsZQ%3D%3D?line=4'>5</a> X_pca = pca.fit_transform(X_train_scaled)
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Downloads/car_analysis/modeling.ipynb#X41sZmlsZQ%3D%3D?line=6'>7</a> # Train random forest model
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Downloads/car_analysis/modeling.ipynb#X41sZmlsZQ%3D%3D?line=7'>8</a> rf_model = RandomForestRegressor(n_estimators=40, random_state=20)
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Downloads/car_analysis/modeling.ipynb#X41sZmlsZQ%3D%3D?line=8'>9</a> rf_model.fit(X_train_scaled, y_train)
#      <a href='vscode-notebook-cell:/c%3A/Users/HP/Downloads/car_analysis/modeling.ipynb#X41sZmlsZQ%3D%3D?line=10'>11</a> # Make predictions on test set
#
# NameError: name 'RandomForestRegressor' is not defined

# %% [markdown]
# A deep learning ANN model

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
tf.random.set_seed(42)

model_3 = tf.keras.Sequential([
    tf.keras.layers.Dense(100,activation="relu"),
    tf.keras.layers.Dense(10,activation="relu"),
    tf.keras.layers.Dense(1)
])

model_3.compile(loss = tf.keras.losses.MAE,optimizer=tf.keras.optimizers.Adam(lr=0.1),metrics=['mae'])

history = model_3.fit(X_train_scaled,y_train,epochs=15)
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/15
# 13479/13479 [==============================] - 39s 3ms/step - loss: 8720.5811 - mae: 8720.5811
# Epoch 2/15
# 13479/13479 [==============================] - 35s 3ms/step - loss: 7260.6143 - mae: 7260.6143
# Epoch 3/15
# 13479/13479 [==============================] - 30s 2ms/step - loss: 7174.0435 - mae: 7174.0435
# Epoch 4/15
# 13479/13479 [==============================] - 32s 2ms/step - loss: 7082.2788 - mae: 7082.2788
# Epoch 5/15
# 13479/13479 [==============================] - 30s 2ms/step - loss: 7011.1089 - mae: 7011.1089
# Epoch 6/15
# 13479/13479 [==============================] - 30s 2ms/step - loss: 6974.1055 - mae: 6974.1055
# Epoch 7/15
# 13479/13479 [==============================] - 30s 2ms/step - loss: 6959.8569 - mae: 6959.8569
# Epoch 8/15
# 13479/13479 [==============================] - 30s 2ms/step - loss: 6953.1665 - mae: 6953.1665
# Epoch 9/15
# 13479/13479 [==============================] - 30s 2ms/step - loss: 6948.9121 - mae: 6948.9121
# Epoch 10/15
# 13479/13479 [==============================] - 30s 2ms/step - loss: 6943.0918 - mae: 6943.0918
# Epoch 11/15
# 13479/13479 [==============================] - 30s 2ms/step - loss: 6932.8389 - mae: 6932.8389
# Epoch 12/15
# 13479/13479 [==============================] - 34s 3ms/step - loss: 6921.9541 - mae: 6921.9541
# Epoch 13/15
# 13479/13479 [==============================] - 37s 3ms/step - loss: 6912.1035 - mae: 6912.1035
# Epoch 14/15
# 13479/13479 [==============================] - 32s 2ms/step - loss: 6900.9209 - mae: 6900.9209
# Epoch 15/15
# 13479/13479 [==============================] - 30s 2ms/step - loss: 6887.5093 - mae: 6887.5093

# %%
# Create a DataFrame to store the accuracy scores
df_scores = pd.DataFrame({'Model': ['Linear Regression', 'Ridge Regression', 'Random Forest'],
                          'R2':[0.29913302194353664, 0.12978522204812015, 0.29911531692534155],
                         "MAE":[ 4131.940411928735,2420.1356765134137, 2420.1356765134137],
                         "MSE":[0.882059874974617,160617726.43756232, 22284497.355930045],
                   })

# %%
df_scores
# Out:
#                Model        R2          MAE           MSE
# 0  Linear Regression  0.299133  4131.940412  8.820599e-01
# 1   Ridge Regression  0.129785  2420.135677  1.606177e+08
# 2      Random Forest  0.299115  2420.135677  2.228450e+07

# %%
df.head()
# Out:
#    Price  Year  Mileage         City State                Vin   Make  \
# 0  15777  2015    25195  New Orleans    LA  KL4CJASB4FB217542  Buick
# 1  16895  2015    21026    Souderton    PA  KL4CJASB9FB190502  Buick
# 2  15995  2015    20496    McDonough    GA  KL4CJBSB2FB101567  Buick
# 3  17991  2016    14806       Tucson    AZ  KL4CJASB7GB620898  Buick
# 4   3950  2003   176935      Elkhart    IN  3G5DA03E93S607122  Buick
#
#                Model
# 0          EncoreFWD
# 1          EncoreFWD
# 2  EncoreConvenience
# 3          EncoreFWD
# 4      RendezvousCXL

# %%
df.drop(columns=['Vin','Make'],inplace=True)

# %%
df.to_csv('modeling.csv', index=False)

# %%
df1 = pd.read_csv("modeling.csv")
df1.head()
# Out:
#    Price  Year  Mileage         City State              Model  Years_Ago  \
# 0  15777  2015    25195  New Orleans    LA          EncoreFWD          8
# 1  16895  2015    21026    Souderton    PA          EncoreFWD          8
# 2  15995  2015    20496    McDonough    GA  EncoreConvenience          8
# 3  17991  2016    14806       Tucson    AZ          EncoreFWD          7
# 4   3950  2003   176935      Elkhart    IN      RendezvousCXL         20
#
#    Avg_Mileage_Per_Year
# 0           3149.375000
# 1           2628.250000
# 2           2562.000000
# 3           2115.142857
# 4           8846.750000

# %%
df1.shape
# Out:
# (539126, 8)
